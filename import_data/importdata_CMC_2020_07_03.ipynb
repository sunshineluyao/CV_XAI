# %% [markdown]
# <a href="https://colab.research.google.com/github/sunshineluyao/CV_ML/blob/master/import_data/importdata_CMC_2020_07_03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # [Readme: Get Started: 3 Ways to Load CSV files into Colab](https://towardsdatascience.com/3-ways-to-load-csv-files-into-colab-7c14fcbdcb92)

# %%
#Mount Google Drive onto your Colab 
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pwd
# Out:
# /content/drive/My Drive

# %%
import os
os.chdir("/content/drive/My Drive/")

# %%
###replace with your own github username and password
# !git clone https://username:password/username/CV_ML.git
# Out:
# Cloning into 'CV_ML'...
# remote: Enumerating objects: 86, done.
# remote: Counting objects: 100% (86/86), done.
# remote: Compressing objects: 100% (74/74), done.
# remote: Total 86 (delta 24), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (86/86), done.

# %%
cd CV_ML/import_data/
# Out:
# /content/drive/My Drive/CV_ML/import_data

# %%
import pandas as pd
import numpy as np
df_CMC=pd.read_csv('CMC_origin_28_04_2013__02_07_2020.csv' )
df_CMC.head()
# Out:
#            Date     Open*      High  ...   Close**          Volume       Market Cap
# 0  Jul 02, 2020  9,231.14  9,274.96  ...  9,123.41  16,338,916,796  168,065,586,387
# 1  Jul 01, 2020  9,145.99  9,309.75  ...  9,228.33  15,971,550,355  169,988,756,578
# 2  Jun 30, 2020  9,185.58  9,217.84  ...  9,137.99  15,735,797,744  168,315,606,321
# 3  Jun 29, 2020  9,140.03  9,237.57  ...  9,190.85  16,460,547,078  169,280,659,246
# 4  Jun 28, 2020  9,048.46  9,197.55  ...  9,143.58  14,560,870,760  168,401,806,137
#
# [5 rows x 7 columns]

# %%
df_CMC.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2623 entries, 0 to 2622
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        2623 non-null   object
#  1   Open*       2623 non-null   object
#  2   High        2623 non-null   object
#  3   Low         2623 non-null   object
#  4   Close**     2623 non-null   object
#  5   Volume      2623 non-null   object
#  6   Market Cap  2623 non-null   object
# dtypes: object(7)
# memory usage: 143.6+ KB

# %%
df_CMC['Date']=pd.to_datetime(df_CMC['Date'])
df_CMC.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2623 entries, 0 to 2622
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        2623 non-null   datetime64[ns]
#  1   Open*       2623 non-null   object
#  2   High        2623 non-null   object
#  3   Low         2623 non-null   object
#  4   Close**     2623 non-null   object
#  5   Volume      2623 non-null   object
#  6   Market Cap  2623 non-null   object
# dtypes: datetime64[ns](1), object(6)
# memory usage: 143.6+ KB

# %%
pd.Timestamp(df_CMC['Date'][0])
# Out:
# Timestamp('2020-07-02 00:00:00')

# %%
df_CMC['Date']=df_CMC['Date'].dt.strftime('%Y-%m-%d')

# %%
df_CMC.head()
# Out:
#          Date     Open*      High  ...   Close**          Volume       Market Cap
# 0  2020-07-02  9,231.14  9,274.96  ...  9,123.41  16,338,916,796  168,065,586,387
# 1  2020-07-01  9,145.99  9,309.75  ...  9,228.33  15,971,550,355  169,988,756,578
# 2  2020-06-30  9,185.58  9,217.84  ...  9,137.99  15,735,797,744  168,315,606,321
# 3  2020-06-29  9,140.03  9,237.57  ...  9,190.85  16,460,547,078  169,280,659,246
# 4  2020-06-28  9,048.46  9,197.55  ...  9,143.58  14,560,870,760  168,401,806,137
#
# [5 rows x 7 columns]

# %%
df_CMC.set_index('Date',drop=True,inplace=True)

# %%
df_CMC.index.name=None
df_CMC.head()
# Out:
#                Open*      High  ...          Volume       Market Cap
# 2020-07-02  9,231.14  9,274.96  ...  16,338,916,796  168,065,586,387
# 2020-07-01  9,145.99  9,309.75  ...  15,971,550,355  169,988,756,578
# 2020-06-30  9,185.58  9,217.84  ...  15,735,797,744  168,315,606,321
# 2020-06-29  9,140.03  9,237.57  ...  16,460,547,078  169,280,659,246
# 2020-06-28  9,048.46  9,197.55  ...  14,560,870,760  168,401,806,137
#
# [5 rows x 6 columns]

# %%
df_CMC['Volume']=df_CMC['Volume'].str.replace(',', '')
df_CMC.head()
# Out:
#                Open*      High  ...       Volume       Market Cap
# 2020-07-02  9,231.14  9,274.96  ...  16338916796  168,065,586,387
# 2020-07-01  9,145.99  9,309.75  ...  15971550355  169,988,756,578
# 2020-06-30  9,185.58  9,217.84  ...  15735797744  168,315,606,321
# 2020-06-29  9,140.03  9,237.57  ...  16460547078  169,280,659,246
# 2020-06-28  9,048.46  9,197.55  ...  14560870760  168,401,806,137
#
# [5 rows x 6 columns]

# %%
df_CMC['Volume']=pd.to_numeric(df_CMC['Volume'])

# %%
df_CMC['Type']='BTC'

# %%
df_Volume = df_CMC[['Volume','Type']]

# %%
df_Volume.head()
# Out:
#                  Volume Type
# 2020-07-02  16338916796  BTC
# 2020-07-01  15971550355  BTC
# 2020-06-30  15735797744  BTC
# 2020-06-29  16460547078  BTC
# 2020-06-28  14560870760  BTC

# %%
###reverse the dataframe: https://www.marsja.se/six-ways-to-reverse-pandas-dataframe/
df_Volume = df_Volume.sort_index(ascending=True)
df_Volume.head(300)
# Out:
#               Volume Type
# 2013-04-28         0  BTC
# 2013-04-29         0  BTC
# 2013-04-30         0  BTC
# 2013-05-01         0  BTC
# 2013-05-02         0  BTC
# ...              ...  ...
# 2014-02-17  31948400  BTC
# 2014-02-18  20015100  BTC
# 2014-02-19  13897800  BTC
# 2014-02-20  46905000  BTC
# 2014-02-21  47308100  BTC
#
# [300 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
df_Volume['Volume'].plot()

# %%
df_Volume.to_csv('Volume.csv')

# %%
import plotly.express as px
### Tutorial https://plotly.com/python/time-series/
####Tutorial Youtube Video https://www.youtube.com/watch?v=kxPZV9ileKI

# %%
# !pip install chart_studio

# %%
import chart_studio
username = 'replace here'
api_key = 'replace with plotly chartstudio api_key in settings'

import chart_studio.plotly as py
import chart_studio.tools as tls

# %%
###Time Series with Range Selector Buttons
fig = px.line(df_Volume, x=df_Volume.index, y='Volume')
fig.update_layout(xaxis_range=['2013-04-28','2020-07-02'],
                  title_text="BTC Volume: from 2013-04-28 to 2020-07-02")
fig.update_xaxes(rangeslider_visible=True)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="d8bd07e3-310c-40fa-addc-df5621afdde1" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("d8bd07e3-310c-40fa-addc-df5621afdde1")) {
#                     Plotly.newPlot(
#                         'd8bd07e3-310c-40fa-addc-df5621afdde1',
# ...

# %%
###Customizing Tick Label Formatting by Zoom Level
fig = px.line(df_Volume, x=df_Volume.index, y='Volume')
fig.update_layout(xaxis_range=['2013-04-28','2020-07-02'],
                  title_text="BTC Volume: from 2013-04-28 to 2020-07-02")
fig.update_xaxes(
    rangeslider_visible=True,
    tickformatstops = [
        dict(dtickrange=[None, 1000], value="%H:%M:%S.%L ms"),
        dict(dtickrange=[1000, 60000], value="%H:%M:%S s"),
        dict(dtickrange=[60000, 3600000], value="%H:%M m"),
        dict(dtickrange=[3600000, 86400000], value="%H:%M h"),
        dict(dtickrange=[86400000, 604800000], value="%e. %b d"),
        dict(dtickrange=[604800000, "M1"], value="%e. %b w"),
        dict(dtickrange=["M1", "M12"], value="%b '%y M"),
        dict(dtickrange=["M12", None], value="%Y Y")
    ]
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="5ed1d853-aafa-42f8-8b35-223c3e2c9601" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("5ed1d853-aafa-42f8-8b35-223c3e2c9601")) {
#                     Plotly.newPlot(
#                         '5ed1d853-aafa-42f8-8b35-223c3e2c9601',
# ...

# %%
###Time Series with Range Selector Buttons
fig = px.line(df_Volume, x=df_Volume.index, y='Volume')
fig.update_layout(xaxis_range=['2013-04-28','2020-07-02'],
                  title_text="BTC Volume: from 2013-04-28 to 2020-07-02")
fig.update_xaxes(
    rangeslider_visible=True,
    rangeselector=dict(
        buttons=list([
            dict(count=1, label="1m", step="month", stepmode="backward"),
            dict(count=6, label="6m", step="month", stepmode="backward"),
            dict(count=1, label="YTD", step="year", stepmode="todate"),
            dict(count=1, label="1y", step="year", stepmode="backward"),
            dict(step="all")
        ])
    )
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="2d2a2cc6-fd8a-4e82-b6b8-2ae1ddce5e50" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("2d2a2cc6-fd8a-4e82-b6b8-2ae1ddce5e50")) {
#                     Plotly.newPlot(
#                         '2d2a2cc6-fd8a-4e82-b6b8-2ae1ddce5e50',
# ...

# %%
#log into your chart studio and replace username and api_key with your own chart studio information. 
###https://chart-studio.plotly.com/settings/api
###log in to plotly chart studio
###Go to settings
###Go to API

chart_studio.tools.set_credentials_file(username='replace here', api_key='replace here')

# %%
py.plot(fig,filename = 'BTC Volume: from 2013-04-28 to 2020-07-02',auto_open=False)
# Out:
# 'https://plotly.com/~zlysunshine2020/4/'

# %%
###file-save a copy to github
